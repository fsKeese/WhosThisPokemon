# %%
import os
import requests
import io
from io import BytesIO
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
pokemon_json = requests.get("https://pokeapi.co/api/v2/pokemon/ditto").json()

# %%
pokemon_image_url = pokemon_json["sprites"]["other"]["official-artwork"]["front_default"]
image_io = requests.get(pokemon_image_url).content

# %%
image = Image.open(io.BytesIO(image_io))

# %%
pokemon_json = requests.get("https://pokeapi.co/api/v2/pokemon/ditto").json()
pokemon_image_url = pokemon_json["sprites"]["other"]["official-artwork"]["front_default"]
image_io = requests.get(pokemon_image_url).content
image = Image.open(io.BytesIO(image_io))
gray_image = image.convert("L")

# %%
img_array = np.copy(np.asarray(image))
height, width, channel = np.where(img_array ==255) 
img_array[height, width, channel] = 0

# %%
plt.imshow(gray_image)

# %%
Image.fromarray(gray_image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 Image.fromarray(gray_image)
#
# File c:\Users\Keese\anaconda3\envs\POKE\lib\site-packages\PIL\Image.py:3122, in fromarray(obj, mode)
#    3119     else:
#    3120         obj = obj.tostring()
# -> 3122 return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#
# File c:\Users\Keese\anaconda3\envs\POKE\lib\site-packages\PIL\Image.py:3029, in frombuffer(mode, size, data, decoder_name, *args)
#    3027 if args[0] in _MAPMODES:
#    3028     im = new(mode, (0, 0))
# -> 3029     im = im._new(core.map_buffer(data, size, decoder_name, 0, args))
#    3030     if mode == "P":
#    3031         from . import ImagePalette
#
# TypeError: expected string or buffer

# %%
np.random.randint(0, 200)
# Out:
# 114
